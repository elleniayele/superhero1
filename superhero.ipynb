# %%
## Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
## Importing the OS and JSON Modules
import os,json

# %%
df1 = pd.read_csv(r"C:\Users\awot1\Downloads\superhero_info - superhero_info.csv")
df1.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
df2 = pd.read_csv(r"C:\Users\awot1\Downloads\superhero_powers - superhero_powers.csv")
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
## save the 2 new columns into the dataframe
df1['Hero|Publisher'].str.split('|',expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
df1[['Hero','Publisher']] = df1['Hero|Publisher'].str.split('|', expand=True) 
## save the 2 new columns into the dataframe
df1.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher
# 0      A-Bomb      Marvel Comics
# 1  Abe Sapien  Dark Horse Comics

# %%
df1[['Height in cm','weight in kg']] = df1['Measurements'].str.split(',', expand=True) 
## save the 2 new columns into the dataframe
df1.head(2)
# Out:
#                  Hero|Publisher Gender           Race Alignment Hair color  \
# 0          A-Bomb|Marvel Comics   Male          Human      good    No Hair
# 1  Abe Sapien|Dark Horse Comics   Male  Icthyo Sapien      good    No Hair
#
#   Eye color Skin color                                  Measurements  \
# 0    yellow    Unknown  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1      blue       blue   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
#
#          Hero          Publisher           Height in cm  \
# 0      A-Bomb      Marvel Comics  {'Height': '203.0 cm'
# 1  Abe Sapien  Dark Horse Comics  {'Height': '191.0 cm'
#
#              weight in kg
# 0   'Weight': '441.0 kg'}
# 1    'Weight': '65.0 kg'}

# %%
df1.drop('weight', axis=1, inplace=True)

# %%
df1.drop("Hero|Publisher", axis=1, inplace=True)

# %%
df1.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher           Height in cm            weight in kg
# 0      Marvel Comics  {'Height': '203.0 cm'   'Weight': '441.0 kg'}
# 1  Dark Horse Comics  {'Height': '191.0 cm'    'Weight': '65.0 kg'}

# %%
lat_long = df1['Height in cm'].apply(pd.Series)
lat_long
# Out:
#                          0
# 0    {'Height': '203.0 cm'
# 1    {'Height': '191.0 cm'
# 2    {'Height': '185.0 cm'
# 3    {'Height': '203.0 cm'
# 4    {'Height': '193.0 cm'
# ..                     ...
# 458  {'Height': '183.0 cm'
# 459  {'Height': '165.0 cm'
# 460   {'Height': '66.0 cm'
# 461  {'Height': '170.0 cm'
# 462  {'Height': '185.0 cm'
#
# [463 rows x 1 columns]

# %%
## examining a single value from the coordinates col
coord = df1.loc[0,"Measurements"]
print(type(coord))
coord
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
coord = coord.replace("'",'"')
coord
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
## now we can use json.loads
fixed_coord = json.loads(coord)
print(type(fixed_coord))
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
## use .str.replace to replace all single quotes
df1['Measurements'] = df1['Measurements'].str.replace("'",'"')
## Apply the json.loads to the full column
df1['Measurements'] = df1['Measurements'].apply(json.loads)
df1['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
lat_long = df1['Measurements'].apply(pd.Series)
lat_long
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# concat long_lat with original dataframe
df1 = pd.concat((df1, lat_long), axis = 1)
df1.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color  \
# 0   Male          Human      good    No Hair    yellow    Unknown
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue
#
#                                    Measurements        Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}      A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}  Abe Sapien
#
#            Publisher           Height in cm            weight in kg    Height  \
# 0      Marvel Comics  {'Height': '203.0 cm'   'Weight': '441.0 kg'}  203.0 cm
# 1  Dark Horse Comics  {'Height': '191.0 cm'    'Weight': '65.0 kg'}  191.0 cm
#
#      Weight
# 0  441.0 kg
# 1   65.0 kg

# %%
df1 = df1.drop(columns=['Measurements'])

# %%
df1=df1.drop(columns=['Height in cm'])

# %%
df1=df1.drop(columns=['weight in kg'], axis=1)

# %%
df1.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher    Height    Weight
# 0      Marvel Comics  203.0 cm  441.0 kg
# 1  Dark Horse Comics  191.0 cm   65.0 kg

# %%
df1.isna().sum().sum()
# Out:
# 0

# %%
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight  cm  kg
# 0         A-Bomb      Marvel Comics  203.0  441.0  cm  kg
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  cm  kg
# 2       Abin Sur          DC Comics  185.0   90.0  cm  kg
# 3    Abomination      Marvel Comics  203.0  441.0  cm  kg
# 4  Absorbing Man      Marvel Comics  193.0  122.0  cm  kg

# %%
df1[['Height in cm ','cm']] = df1['Height'].str.split(' ', expand=True) 
## save the 2 new columns into the dataframe
df1.head(2)

# %%
df1[['Weight','kg']] = df1['Weight'].str.split(' ', expand=True) 
## save the 2 new columns into the dataframe
df1.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height Weight  cm  kg
# 0      Marvel Comics  203.0  441.0  cm  kg
# 1  Dark Horse Comics  191.0   65.0  cm  kg

# %%
df1.drop('kg', axis=1, inplace=True)

# %%
df1.drop('cm', axis=1, inplace= True)

# %%
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0
# 2       Abin Sur          DC Comics  185.0   90.0
# 3    Abomination      Marvel Comics  203.0  441.0
# 4  Absorbing Man      Marvel Comics  193.0  122.0

# %% [markdown]
# # second dataframe

# %%
df2.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# Plus, one-hot-encoded columns for every power that appears in the dataset. E.g.:
# Agility
# Flight
# Superspeed
# etc.
# Hint: There is a space in "100 kg" or "52.5 cm"

# %%
df2['Power_split']= df2['Powers'].str.split(',') 
df2.head(5)
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                          Power_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
df2['Power_split'].value_counts()
# Out:
# [Intelligence]                                                                                                                                                                                                                                                                          8
# [Durability, Super Strength]                                                                                                                                                                                                                                                            5
# [Agility, Stealth, Marksmanship, Weapons Master, Stamina]                                                                                                                                                                                                                               4
# ...

# %%
exploded = df2.explode('Power_split')
exploded[['hero_names','Power_split','Powers']].head(5)
# Out:
#   hero_names          Power_split  \
# 0    3-D Man              Agility
# 0    3-D Man       Super Strength
# 0    3-D Man              Stamina
# 0    3-D Man          Super Speed
# 1     A-Bomb  Accelerated Healing
#
#                                               Powers
# 0         Agility,Super Strength,Stamina,Super Speed
# 0         Agility,Super Strength,Stamina,Super Speed
# 0         Agility,Super Strength,Stamina,Super Speed
# 0         Agility,Super Strength,Stamina,Super Speed
# 1  Accelerated Healing,Durability,Longevity,Super...

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['Power_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    df2[col] = df2['Powers'].str.contains(col)
df2.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                          Power_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# 2  [Agility, Accelerated Healing, Cold Resistance...     True            True
# 3                               [Lantern Power Ring]    False           False
# 4  [Accelerated Healing, Intelligence, Super Stre...    False            True
#
#    Stamina  Super Speed  Accelerated Healing  Durability  Longevity  ...  \
# ...

# %%
# drop transactions clumns
df2 = df2.drop(columns=['Powers','Power_split'])
## save data for next lesson
df2.to_csv('advanced_tf_data_pt1.csv', index=False)

# %%
df2.head()
# Out:
#     hero_names  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %%
df1.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight
# 0         A-Bomb      Marvel Comics  203.0  441.0
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0
# 2       Abin Sur          DC Comics  185.0   90.0
# 3    Abomination      Marvel Comics  203.0  441.0
# 4  Absorbing Man      Marvel Comics  193.0  122.0

# %%
## merging with different column names
merge_res=pd.merge(df1,df2, left_on='Hero', right_on='hero_names')
merge_res.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher Height Weight  ... Weather Control  \
# 0         A-Bomb      Marvel Comics  203.0  441.0  ...           False
# 1     Abe Sapien  Dark Horse Comics  191.0   65.0  ...           False
# 2       Abin Sur          DC Comics  185.0   90.0  ...           False
# 3    Abomination      Marvel Comics  203.0  441.0  ...           False
# 4  Absorbing Man      Marvel Comics  193.0  122.0  ...           False
#
#    Omnipresent  Omniscient  Hair Manipulation  Nova Force  Odin Force  \
# ...

# %% [markdown]
# 1.Compare the average weight of super powers who have Super Speed to those who do not.

# %%
merge_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Columns: 178 entries, Gender to Changing Armor
# dtypes: bool(167), object(11)
# memory usage: 118.9+ KB

# %%
merge_res["Weight"] = pd.to_numeric(merge_res["Weight"])

# %%
merge_res.groupby('Super Speed')['Weight'].mean()
# Out:
# Super Speed
# False    101.773585
# True     129.404040
# Name: Weight, dtype: float64

# %% [markdown]
# 2.What is the average height of heroes for each publisher?

# %%
merge_res["Height"] = pd.to_numeric(merge_res["Height"])

# %%
merge_res.groupby('Publisher')['Height'].mean()
# Out:
# Publisher
# DC Comics            181.923913
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.546128
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height, dtype: float64
